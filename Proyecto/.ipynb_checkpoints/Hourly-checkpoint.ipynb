# %%
import pandas as pd

# %%
def mytabla(data):
    nulls = pd.DataFrame(data.isnull().sum()/data.shape[0]*100, columns=['% de datos nulos'])
    ceros = pd.DataFrame((data==0).sum()/data.shape[0]*100, columns=['% de ceros'])
    tipo = pd.DataFrame(data.dtypes,columns=['Tipo de datos'])
    val = pd.DataFrame(data.nunique(),columns=['# de valores diferentes'])
    mis_val_table = pd.concat([nulls, ceros,tipo, val], axis=1)
    return mis_val_table

# %%
def eliminar_coma(x):
    x=str(x).replace(',','.')
    return x

# %%
name = r"C:\Users\jibar\OneDrive - Universidad de los andes\Clases_Maestria\CIENCIA DE DATOS\Proyecto\General\General\Data\Hourly.csv"

data =pd.read_csv(name,sep='|',error_bad_lines=False, warn_bad_lines= False,index_col=False,header=0, low_memory=False)

# %%
data.shape
# Out:
# (9770958, 20)

# %%
mytabla(data)
# Out:
#                  % de datos nulos  % de ceros Tipo de datos  \
# id_sitio                 0.000000         0.0         int64
# corte_evento             0.000000       100.0          bool
# Hourly_Date              0.000000         0.0        object
# VolUnCorrected           0.001341         0.0        object
# VolCorrected             0.002999         0.0        object
# Pressure                 0.224819         0.0        object
# Temperature              0.225341         0.0        object
# MaxPressure             37.528040         0.0        object
# MaxPressureTime         37.528459         0.0        object
# MinPressure             37.528459         0.0        object
# MinPressureTime         37.528603         0.0        object
# MaxFlow                 37.528603         0.0        object
# maxFlowTime             37.528920         0.0        object
# MinFlow                 37.528920         0.0        object
# MinFlowTime             37.529022         0.0        object
# MaxTemp                 37.529022         0.0        object
# maxTempTime             37.529043         0.0        object
# MinTemp                 37.529063         0.0        object
# MinTempTime             37.529073         0.0        object
# id_RTU                   0.003695         0.0       float64
#
#                  # de valores diferentes
# id_sitio                             307
# corte_evento                           1
# Hourly_Date                        39115
# VolUnCorrected                     51841
# VolCorrected                      340921
# Pressure                           49382
# Temperature                         7074
# MaxPressure                        30849
# MaxPressureTime                  5210233
# MinPressure                        29706
# MinPressureTime                  5326477
# MaxFlow                           366564
# maxFlowTime                      5062150
# MinFlow                           242608
# MinFlowTime                      3239461
# MaxTemp                             6904
# maxTempTime                      5273576
# MinTemp                             6288
# MinTempTime                      5255229
# id_RTU                               312

# %%
data.head()
# Out:
#    id_sitio  corte_evento          Hourly_Date      VolUnCorrected  \
# 0        35         False  2013-08-07 09:00:01                  75
# 1        41         False  2013-08-07 08:00:01                  20
# 2        72         False  2013-08-07 18:00:01  136,86000000000001
# 3        80         False  2013-08-07 06:00:01                  39
# 4        90         False  2013-08-07 14:00:01                   0
#
#          VolCorrected Pressure Temperature MaxPressure      MaxPressureTime  \
# 0  379,61000000000001      NaN         NaN           0  2013-08-07 00:00:00
# 1  349,67000000000002      NaN         NaN           0  2013-08-07 00:00:00
# 2  661,97000000000003      NaN         NaN           0  2013-08-07 00:00:00
# 3              195,09      NaN         NaN           0  2013-08-07 00:00:00
# 4                   0      NaN         NaN           0  2013-08-07 00:00:00
#
#   MinPressure      MinPressureTime MaxFlow          maxFlowTime MinFlow  \
# 0           0  2013-08-07 00:00:00       0  2013-08-07 00:00:00       0
# 1           0  2013-08-07 00:00:00       0  2013-08-07 00:00:00       0
# 2           0  2013-08-07 00:00:00       0  2013-08-07 00:00:00       0
# 3           0  2013-08-07 00:00:00       0  2013-08-07 00:00:00       0
# 4           0  2013-08-07 00:00:00       0  2013-08-07 00:00:00       0
#
#            MinFlowTime MaxTemp          maxTempTime MinTemp  \
# 0  2013-08-07 00:00:00       0  2013-08-07 00:00:00       0
# 1  2013-08-07 00:00:00       0  2013-08-07 00:00:00       0
# 2  2013-08-07 00:00:00       0  2013-08-07 00:00:00       0
# 3  2013-08-07 00:00:00       0  2013-08-07 00:00:00       0
# 4  2013-08-07 00:00:00       0  2013-08-07 00:00:00       0
#
#            MinTempTime  id_RTU
# 0  2013-08-07 00:00:00    82.0
# 1  2013-08-07 00:00:00    89.0
# 2  2013-08-07 00:00:00   111.0
# 3  2013-08-07 00:00:00   124.0
# 4  2013-08-07 00:00:00   149.0

# %%
data.dtypes
# Out:
# id_sitio             int64
# corte_evento          bool
# Hourly_Date         object
# VolUnCorrected      object
# VolCorrected        object
# Pressure            object
# Temperature         object
# MaxPressure         object
# MaxPressureTime     object
# MinPressure         object
# MinPressureTime     object
# MaxFlow             object
# maxFlowTime         object
# MinFlow             object
# MinFlowTime         object
# MaxTemp             object
# maxTempTime         object
# MinTemp             object
# MinTempTime         object
# id_RTU             float64
# dtype: object

# %%
data['VolUnCorrected']=data['VolUnCorrected'].apply(eliminar_coma)
data['VolCorrected']=data['VolCorrected'].apply(eliminar_coma)
data['Pressure']=data['Pressure'].apply(eliminar_coma)
data['Temperature']=data['Temperature'].apply(eliminar_coma)
data['MaxPressure']=data['MaxPressure'].apply(eliminar_coma)


data['MinPressure']=data['MinPressure'].apply(eliminar_coma)

data['MaxFlow']=data['MaxFlow'].apply(eliminar_coma)

data['MinFlow']=data['MinFlow'].apply(eliminar_coma)

data['MaxTemp']=data['MaxTemp'].apply(eliminar_coma)

data['MinTemp']=data['MinTemp'].apply(eliminar_coma)



convert = {'id_sitio':'object',
          'VolUnCorrected':float,
          'VolCorrected':float,
          'Pressure':float,
          'Temperature':float,
          'MaxPressure':float,
          'MinPressure':float,
          'MaxFlow':float,
          'MinFlow':float,
          'MaxTemp':float,
          'MinTemp':float,
          'id_RTU':'object'}
data = data.astype(convert)

# %% [markdown]
# ## desde este punto se puede entender mejor lo que hay en la BD

# %%
data.shape
# Out:
# (9770958, 20)

# %%
data.dtypes
# Out:
# id_sitio            object
# corte_evento          bool
# Hourly_Date         object
# VolUnCorrected     float64
# VolCorrected       float64
# Pressure           float64
# Temperature        float64
# MaxPressure        float64
# MaxPressureTime     object
# MinPressure        float64
# MinPressureTime     object
# MaxFlow            float64
# maxFlowTime         object
# MinFlow            float64
# MinFlowTime         object
# MaxTemp            float64
# maxTempTime         object
# MinTemp            float64
# MinTempTime         object
# id_RTU              object
# dtype: object

# %%
mytabla(data)
# Out:
#                  % de datos nulos  % de ceros Tipo de datos  \
# id_sitio                 0.000000    0.000000        object
# corte_evento             0.000000  100.000000          bool
# Hourly_Date              0.000000    0.000000        object
# VolUnCorrected           0.001341   14.191178       float64
# VolCorrected             0.002999   13.940516       float64
# Pressure                 0.224819    1.281573       float64
# Temperature              0.225341    1.204682       float64
# MaxPressure             37.528040    0.813216       float64
# MaxPressureTime         37.528459    0.000000        object
# MinPressure             37.528459    0.814598       float64
# MinPressureTime         37.528603    0.000000        object
# MaxFlow                 37.528603   18.548130       float64
# maxFlowTime             37.528920    0.000000        object
# MinFlow                 37.528920   34.494499       float64
# MinFlowTime             37.529022    0.000000        object
# MaxTemp                 37.529022    0.815386       float64
# maxTempTime             37.529043    0.000000        object
# MinTemp                 37.529063    0.818814       float64
# MinTempTime             37.529073    0.000000        object
# id_RTU                   0.003695    0.000000        object
#
#                  # de valores diferentes
# id_sitio                             307
# corte_evento                           1
# Hourly_Date                        39115
# VolUnCorrected                     51841
# VolCorrected                      340921
# Pressure                           49382
# Temperature                         7074
# MaxPressure                        30849
# MaxPressureTime                  5210233
# MinPressure                        29706
# MinPressureTime                  5326477
# MaxFlow                           366564
# maxFlowTime                      5062150
# MinFlow                           242608
# MinFlowTime                      3239461
# MaxTemp                             6904
# maxTempTime                      5273576
# MinTemp                             6288
# MinTempTime                      5255229
# id_RTU                               312

# %%
numer = data.select_dtypes([float])
objeto= data.select_dtypes(['object'])

# %%
numer.describe()
# Out:
#        VolUnCorrected  VolCorrected      Pressure   Temperature   MaxPressure  \
# count    9.770827e+06  9.770665e+06  9.748991e+06  9.748940e+06  6.104109e+06
# mean     3.947384e+01  3.918196e+02  1.423607e+02  2.535587e+01  1.449091e+02
# std      2.902101e+02  2.642995e+03  1.091251e+02  5.857381e+00  9.172640e+01
# min     -2.538105e+04 -1.936114e+05 -3.643000e+01 -3.888000e+02 -1.313000e+01
# 25%      3.000000e+00  3.000000e+01  5.873000e+01  2.378000e+01  5.984000e+01
# 50%      1.200000e+01  1.081200e+02  1.014900e+02  2.632000e+01  1.013200e+02
# 75%      4.025000e+01  3.287900e+02  2.354500e+02  2.818000e+01  2.415200e+02
# max      4.471710e+05  6.909445e+06  9.541100e+04  8.874300e+02  9.824900e+02
#
#         MinPressure       MaxFlow       MinFlow       MaxTemp       MinTemp
# count  6.104068e+06  6.104054e+06  6.104023e+06  6.104013e+06  6.104009e+06
# mean   1.401532e+02  4.869428e+02  1.878742e+02  2.569832e+01  2.460858e+01
# std    8.961870e+01  8.027606e+02  4.799771e+02  1.032084e+01  8.612575e+00
# min   -1.313000e+01  0.000000e+00 -2.093000e+02 -6.570000e+00 -1.222000e+01
# 25%    5.873000e+01  0.000000e+00  0.000000e+00  2.398000e+01  2.286000e+01
# 50%    9.999000e+01  1.131900e+02  0.000000e+00  2.675000e+01  2.584000e+01
# 75%    2.339700e+02  7.109100e+02  1.235000e+02  2.850000e+01  2.769000e+01
# max    5.203000e+02  9.553347e+04  7.962220e+03  1.251233e+04  1.206933e+04

# %%
numer['MaxTemp'].value_counts()
# Out:
#  0.00     79671
#  25.00    45711
#  27.00    11696
#  27.36    11663
#  27.16    11660
#           ...
# -1.47         1
#  61.39        1
#  64.40        1
#  77.90        1
#  68.64        1
# Name: MaxTemp, Length: 6904, dtype: int64

# %%
objeto.describe()
# Out:
#         id_sitio          Hourly_Date      MaxPressureTime  \
# count    9770958              9770958              6104068
# unique       307                39115              5210233
# top           92  2014-02-19 23:59:59  2013-09-04 00:00:00
# freq       39198                  633                 4453
#
#             MinPressureTime          maxFlowTime          MinFlowTime  \
# count               6104054              6104023              6104013
# unique              5326477              5062150              3239461
# top     2013-09-04 00:00:00  2013-09-04 00:00:00  2013-09-04 00:00:00
# freq                   4453                 4453                 4453
#
#                 maxTempTime          MinTempTime     id_RTU
# count               6104011              6104008  9770597.0
# unique              5273576              5255229      312.0
# top     2013-09-04 00:00:00  2013-09-04 00:00:00      900.0
# freq                   4453                 4453   108936.0

# %%
import matplotlib.pyplot as plt

# %%
numer.columns
# Out:
# Index(['VolUnCorrected', 'VolCorrected', 'Pressure', 'Temperature',
#        'MaxPressure', 'MinPressure', 'MaxFlow', 'MinFlow', 'MaxTemp',
#        'MinTemp'],
#       dtype='object')

# %%
fig =plt.figure(figsize=(14,12))
cont = 0 
for i in numer.columns:
    cont+=1
    ax = plt.subplot(5,2,cont)
    plt.hist(numer[i], bins=50, density=True)
    ax.title.set_text(i)
    plt.ylim(0, 0.25)# modificar a 1 para ver la totalidad
fig.tight_layout(pad=2.0)
# Out:
# c:\users\jibar\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# c:\users\jibar\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
fig =plt.figure(figsize=(14,12))
cont = 0 
for i in numer.columns:
    cont+=1
    ax = plt.subplot(5,2,cont)
    plt.hist(numer[i], bins=50, density=True)
    ax.title.set_text(i)
    plt.ylim(0, 0.00000001)# modificar a 1 para ver la totalidad
fig.tight_layout(pad=2.0)

# %%
plt.figure(figsize = (14,4))
plt.subplot(1,2,1)
plt.bar(x = objeto['id_sitio'].value_counts().index,height=objeto['id_sitio'].value_counts().values,   width=2)

plt.subplot(1,2,2)
plt.bar(x = objeto['id_RTU'].value_counts().index,height=objeto['id_RTU'].value_counts().values,   width=1.2)
# Out:
# <BarContainer object of 312 artists>

# %%
numer.corr()
# Out:
#                 VolUnCorrected  VolCorrected  Pressure  Temperature  \
# VolUnCorrected        1.000000      0.743344 -0.014059    -0.046912
# VolCorrected          0.743344      1.000000  0.048693    -0.054721
# Pressure             -0.014059      0.048693  1.000000     0.120961
# Temperature          -0.046912     -0.054721  0.120961     1.000000
# MaxPressure          -0.030865      0.032116  0.964551     0.206607
# MinPressure          -0.030462      0.032191  0.962019     0.197335
# MaxFlow               0.091307      0.099195  0.273309     0.081672
# MinFlow               0.182012      0.370205  0.156708    -0.037675
# MaxTemp              -0.038064     -0.046914  0.081764     0.360508
# MinTemp              -0.042736     -0.044911  0.109098     0.424547
#
#                 MaxPressure  MinPressure   MaxFlow   MinFlow   MaxTemp  \
# VolUnCorrected    -0.030865    -0.030462  0.091307  0.182012 -0.038064
# VolCorrected       0.032116     0.032191  0.099195  0.370205 -0.046914
# Pressure           0.964551     0.962019  0.273309  0.156708  0.081764
# Temperature        0.206607     0.197335  0.081672 -0.037675  0.360508
# MaxPressure        1.000000     0.994432  0.278009  0.155039  0.130888
# MinPressure        0.994432     1.000000  0.264388  0.161594  0.124051
# MaxFlow            0.278009     0.264388  1.000000  0.643748  0.044718
# MinFlow            0.155039     0.161594  0.643748  1.000000 -0.034841
# MaxTemp            0.130888     0.124051  0.044718 -0.034841  1.000000
# MinTemp            0.164099     0.159918  0.044196 -0.022082  0.845322
#
#                  MinTemp
# VolUnCorrected -0.042736
# VolCorrected   -0.044911
# Pressure        0.109098
# Temperature     0.424547
# MaxPressure     0.164099
# MinPressure     0.159918
# MaxFlow         0.044196
# MinFlow        -0.022082
# MaxTemp         0.845322
# MinTemp         1.000000

# %%
import seaborn as sns
sns.heatmap(numer.corr())

# %%
numer.corr(method ='spearman')
# Out:
#                 VolUnCorrected  VolCorrected  Pressure  Temperature  \
# VolUnCorrected        1.000000      0.924018 -0.074598     0.039883
# VolCorrected          0.924018      1.000000  0.227181     0.078907
# Pressure             -0.074598      0.227181  1.000000     0.075485
# Temperature           0.039883      0.078907  0.075485     1.000000
# MaxPressure          -0.126537      0.175845  0.931252     0.127434
# MinPressure          -0.110500      0.192194  0.933150     0.107405
# MaxFlow               0.407405      0.485075  0.244234     0.186421
# MinFlow               0.453249      0.489963  0.173609    -0.053270
# MaxTemp               0.018271      0.069126  0.102269     0.884029
# MinTemp               0.057089      0.117699  0.125827     0.881495
#
#                 MaxPressure  MinPressure   MaxFlow   MinFlow   MaxTemp  \
# VolUnCorrected    -0.126537    -0.110500  0.407405  0.453249  0.018271
# VolCorrected       0.175845     0.192194  0.485075  0.489963  0.069126
# Pressure           0.931252     0.933150  0.244234  0.173609  0.102269
# Temperature        0.127434     0.107405  0.186421 -0.053270  0.884029
# MaxPressure        1.000000     0.971424  0.235694  0.124289  0.139338
# MinPressure        0.971424     1.000000  0.207571  0.184140  0.107656
# MaxFlow            0.235694     0.207571  1.000000  0.535424  0.197146
# MinFlow            0.124289     0.184140  0.535424  1.000000 -0.092236
# MaxTemp            0.139338     0.107656  0.197146 -0.092236  1.000000
# MinTemp            0.155331     0.143779  0.174926 -0.006852  0.942176
#
#                  MinTemp
# VolUnCorrected  0.057089
# VolCorrected    0.117699
# Pressure        0.125827
# Temperature     0.881495
# MaxPressure     0.155331
# MinPressure     0.143779
# MaxFlow         0.174926
# MinFlow        -0.006852
# MaxTemp         0.942176
# MinTemp         1.000000

# %%
sns.heatmap(numer.corr(method ='spearman'))
